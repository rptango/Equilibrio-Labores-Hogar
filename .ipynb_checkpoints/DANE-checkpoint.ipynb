# %%
library(foreign)

# %%
datos5<-read.spss("./dataset/EAS_2019.sav", to.data.frame = TRUE)

datos6<-read.dta("./dataset/EAS_2019.dta")

# %%
datos6
# Out:
#      idnoremp Seccion18 Division periodo intio     pottcag gppgpa ocgtot
# 1    10001    I1        55       2019      2690535   0      29546   1108203
# 2    10002    I1        55       2019      5198956   0      19692   2774045
# 3    10003    I1        55       2019     14153289 117      39744  10230734
# 4    10004    I1        55       2019     10684133   0      20703   7825096
# 5    10005    I2        56       2019     26319862 177      33787  23404650
# 6    10006    I2        56       2019     84361203   0      83862  51640157
# 7    10007    I2        56       2019      1289475   0      14689    537600
# 8    10008    I2        56       2019     15431445  56      36526  11032273
# 9    10012    H1        52       2019       350353   0          0    212327
# 10   10013    H1        52       2019     24063044   6      30088  17705608
# 11   10015    H1        52       2019     20528645   0      24207   7656430
# ...
